# %% [markdown]
# # **Flexão de vigas**
# *Professor Rafael Barros*
# ___
#
# ## Tensões de flexão em vigas
# De acordo com a teoria clássica de vigas, as tensões normais de flexão em uma seção transversal podem ser determinadas através da equação a a seguir:
#
# $\sigma_x = \frac{N}{A} - \frac{M_z y}{I_z} + \frac{M_y z}{I_y}$ <br>
#
# Onde:<br>
# * **N** é a força normal na seção
# * **A** é a área da seção
# * **$M_z$**, **$M_y$** são os momentos fletores em torno dos eixos z e y, respectivamente
# * **$I_z$**, **$I_y$** são os momentos de inércia em torno dos eixos z e y, respectivamente
# * **z**, **y** são as coordenadas da superfície da seção transversal

# %% [markdown]
# ## Exemplo - seção retangular

# %%
#Funções utilizadas
from FuncoesFlexao import TensFlexRet

#Dados de entrada
b = 20 #cm (largura da base)
h = 40 #cm (altura)
Mz = 11 #kNm (momento em torno de z: +compressão no topo, -compressão na base)
My = 11 #kNm (momento em torno de y: +compressão à direita, -compressão à esquerda)
N = -200 #kN (Esforço normal na seção: +tração, -compressão)

#Cálculos
TensFlexRet(b, h, Mz, My, N)
# Out:
# =================================================================
#                     RESISTÊNCIA DOS MATERIAIS
#                      Professor Rafael Barros
# =================================================================
#
# DISTRIBUIÇÃO DE TENSÕES DE FLEXÃO EM UMA VIGA DE SEÇÃO RETANGULAR
# -----------------------------------------------------------------
# Momento em torno de z:              Mz        = 11.00 kNm
# Momento em torno de y:              My        = 11.00 kNm
# Momento fletor resultante:          M         = 15.56 kNm
# Ângulo do momento solicitante:      theta     = 45.00 °
# Esforço normal:                     N         = -200.00 kN
# Momento de inércia em relação a z:  Iz        = 106666.67 cm4
# Momento de inércia em relação a y:  Iy        = 26666.67 cm4
# Tensão normal máxima:               sigma_max = 3.69 MPa
# Tensão normal mínima:               sigma_min = -8.69 MPa
# Inclinação da linha neutra:         alpha     = 79.14 °
# -----------------------------------------------------------------

# %% [markdown]
# ## Exemplo - seção em I

# %%
from FuncoesFlexao import TensFlexI

d = 40
bf = 20
tw = 1
tf = 2
Mz = 11 #kNm (momento em torno de z: +compressão no topo, -compressão na base)
My = 1 #kNm (momento em torno de y: +compressão à direita, -compressão à esquerda)
N = -25 #kN

TensFlexI(d, bf, tf, tw, Mz, My, N)
# Out:
# =================================================================
#                     RESISTÊNCIA DOS MATERIAIS
#                      Professor Rafael Barros
# =================================================================
#
# DISTRIBUIÇÃO DE TENSÕES DE FLEXÃO EM UMA VIGA DE SEÇÃO EM I
# -----------------------------------------------------------------
# Momebnto em torno de z:             Mz        = 11.00 kNm
# Momebnto em torno de y:             My        = 1.00 kNm
# Momento fletor resultante:          M         = 11.05 kNm
# Ângulo do momento solicitante:      theta     = 5.19 °
# Esforço normal:                     N         = -25.00 kN
# Momento de inércia em relação a z:  Iz        = 32794.67 cm4
# Momento de inércia em relação a y:  Iy        = 2669.67 cm4
# Tensão normal máxima:               sigma_max = 8.30 MPa
# Tensão normal mínima:               sigma_min = -12.61 MPa
# Inclinação da linha neutra:         alpha     = 55.19 °
# -----------------------------------------------------------------
